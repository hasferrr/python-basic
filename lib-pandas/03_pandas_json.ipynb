# %% [markdown]
# ## Pandas Read JSON
#
# - Big data sets are often stored, or extracted as JSON.
# - JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.

# %%
import pandas as pd

df = pd.read_json('files/artifacts.GOOD.json')
df
# Out:
#    format  version   source                                          artifacts
# 0    GOOD        1  Amenoma  {'setKey': 'EmblemOfSeveredFate', 'slotKey': '...
# 1    GOOD        1  Amenoma  {'setKey': 'EmblemOfSeveredFate', 'slotKey': '...
# 2    GOOD        1  Amenoma  {'setKey': 'EmblemOfSeveredFate', 'slotKey': '...
# 3    GOOD        1  Amenoma  {'setKey': 'EmblemOfSeveredFate', 'slotKey': '...
# 4    GOOD        1  Amenoma  {'setKey': 'EmblemOfSeveredFate', 'slotKey': '...
# ..    ...      ...      ...                                                ...
# 81   GOOD        1  Amenoma  {'setKey': 'ViridescentVenerer', 'slotKey': 'c...
# 82   GOOD        1  Amenoma  {'setKey': 'ViridescentVenerer', 'slotKey': 'c...
# 83   GOOD        1  Amenoma  {'setKey': 'GladiatorsFinale', 'slotKey': 'san...
# 84   GOOD        1  Amenoma  {'setKey': 'EmblemOfSeveredFate', 'slotKey': '...
# 85   GOOD        1  Amenoma  {'setKey': 'EmblemOfSeveredFate', 'slotKey': '...
#
# [86 rows x 4 columns]

# %% [markdown]
# ### Dictionary as JSON

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

data_df = pd.DataFrame(data)

print(data_df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300
